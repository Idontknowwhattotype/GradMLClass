# %% [markdown]
# # Lab 4-1: The Wonderful World of Ramen
#
# ## Ramen Rater Background
#
# [The Ramen Rater](https://www.theramenrater.com/) has been publishing reviews of ramen noodles for years. They have collected the highlights of their reviews of 2700 ramen varieties in a single dataset. In what country is the best ramen made? Does the best ramen come in a bowl, a cup, or a pack? What company makes the best (and worst) ramen?
#
# Let's find out!
#
# <hr />
#
# The entire dataset is available [here](https://www.theramenrater.com/resources-2/the-list/), as a web table, a PDF, and a spreadsheet.
#
# Import The Ramen Rater's BIG LIST of ramen reviews from `ramen_ratings.csv` and view the first few records.
#
# - Import `pandas` as `pd` and `matplotlib.pyplot` as `plt`.
# - Use the pandas function `read_csv()` to read `ramen_ratings.csv` from the folder `datasets` into a pandas dataframe called `ramen`.
# - Use `print()` and `head()` to show the first few rows of the dataframe.
#
# <hr />
#
# ## Some Good References
#
# Here is a helpful [Pandas cheatsheet](https://github.com/pandas-dev/pandas/blob/master/doc/cheatsheet/Pandas_Cheat_Sheet.pdf) to remind you of some of the basic commands and workflows we'll be exploring here. Another great reference for pertinent skills and terms is introduced in [Python Data Science Toolbox, Part 1](https://campus.datacamp.com/courses/python-data-science-toolbox-part-1/). Please do feel free to review the slides and exercises there as you go through this project.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
### TODO
# Import pandas as pd and matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt

# Read in the ramen_ratings.csv file
ramen = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/ML Class/Week 4/Ramen/ramen_ratings.csv')

# Print the first 5 records of 'ramen'
ramen.head()
# Out:
#    review     brand                                            variety style  \
# 0    2700     Vedan                    Jhen Mian Tang Spicy Hot Noodle  Pack
# 1    2699     Myojo                        Chicken Shio Wanton Noodles  Bowl
# 2    2698    Nissin  Cup Noodles Chilli Crab Flavour (More Crabtastic)   Cup
# 3    2697  Maruchan  Bowl Taste Of Asia Hot & Spicy Kimchi Ramen Ra...  Bowl
# 4    2696  Nongshim                  Neoguri Spicy Seafood Noodle Soup   Cup
#
#          country rating top_ten
# 0         Taiwan      4     NaN
# 1          Japan    4.5     NaN
# 2      Singapore      4     NaN
# 3  United States   3.25     NaN
# 4  United States      5     NaN

# %% [markdown]
# ## Ramen throughout the world
#
# Ramen noodles come from all over the world so let's get an idea about where they're from. Let's start by printing each country in `ramen`.
#
# - Create a `for` loop that iterates through each entry in the `country` column in `ramen`.
# - Inside your `for` loop, print the country.
#
# <hr />
#
# This will print a really long list with a lot of duplicates. But don't worry, we'll clean it up shortly.

# %%
# Loop through countries in 'ramen'
for i in ramen['country']:
    print(i)
# Out:
# Taiwan
# Japan
# Singapore
# United States
# United States
# Taiwan
# Phlippines
# China
# Singapore
# Hong Kong
# Japan
# United States
# Singapore
# Japan
# Japan
# India
# Singapore
# Japan
# China
# Japan
# South Korea
# Malaysia
# India
# Singapore
# United States
# Japan
# Singapore
# Hong Kong
# Taiwan
# Japan
# China
# Singapore
# South Korea
# Japan
# United States
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# South Korea
# Singapore
# South Korea
# Japan
# India
# Taiwan
# South Korea
# Singapore
# Japan
# Japan
# Japan
# India
# Hong Kong
# South Korea
# Japan
# Japan
# South Korea
# Japan
# Hong Kong
# Japan
# United States
# Japan
# South Korea
# Japan
# India
# Singapore
# Japan
# South Korea
# Japan
# India
# South Korea
# China
# Singapore
# Singapore
# South Korea
# Hong Kong
# South Korea
# Japan
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# Taiwan
# South Korea
# Singapore
# China
# Japan
# India
# Japan
# South Korea
# Hong Kong
# Japan
# South Korea
# Nigeria
# Japan
# Japan
# China
# South Korea
# Hong Kong
# India
# United States
# United States
# Malaysia
# Japan
# Japan
# South Korea
# Japan
# Taiwan
# United States
# Taiwan
# India
# South Korea
# Japan
# Japan
# Japan
# Singapore
# Thailand
# United States
# South Korea
# Japan
# Hong Kong
# Singapore
# India
# United States
# Vietnam
# South Korea
# Hong Kong
# United States
# Singapore
# United States
# India
# South Korea
# Ghana
# Japan
# Malaysia
# Singapore
# South Korea
# Indonesia
# South Korea
# China
# Japan
# Singapore
# United States
# Singapore
# Japan
# United States
# Taiwan
# Hong Kong
# United States
# Singapore
# Ghana
# United States
# Japan
# South Korea
# Japan
# China
# South Korea
# Japan
# Singapore
# Vietnam
# South Korea
# Japan
# Singapore
# South Korea
# Japan
# Singapore
# Singapore
# South Korea
# Japan
# Japan
# Japan
# Taiwan
# Japan
# United States
# Taiwan
# South Korea
# Malaysia
# India
# South Korea
# Indonesia
# Singapore
# Japan
# South Korea
# China
# Nigeria
# Taiwan
# Malaysia
# Singapore
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# Hungary
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# South Korea
# Taiwan
# South Korea
# Japan
# Malaysia
# Taiwan
# Taiwan
# South Korea
# Japan
# South Korea
# Japan
# Taiwan
# Hong Kong
# United States
# Singapore
# Japan
# South Korea
# Hong Kong
# China
# South Korea
# Indonesia
# Taiwan
# Japan
# United States
# Japan
# South Korea
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Mexico
# Japan
# China
# Taiwan
# Indonesia
# Japan
# Hong Kong
# Vietnam
# Taiwan
# Japan
# Thailand
# United States
# Malaysia
# Japan
# Taiwan
# Japan
# United States
# Hong Kong
# South Korea
# Taiwan
# Mexico
# Taiwan
# China
# Japan
# Japan
# Indonesia
# China
# Japan
# Taiwan
# Hong Kong
# United States
# United States
# United States
# United States
# United States
# Taiwan
# China
# Hong Kong
# Singapore
# United States
# India
# China
# Singapore
# Indonesia
# China
# South Korea
# Fiji
# China
# Hong Kong
# Japan
# Malaysia
# South Korea
# Hong Kong
# United States
# China
# Hong Kong
# Fiji
# Taiwan
# China
# United States
# South Korea
# Hong Kong
# South Korea
# United States
# Hong Kong
# Malaysia
# Thailand
# Taiwan
# Indonesia
# India
# China
# Japan
# South Korea
# South Korea
# South Korea
# South Korea
# South Korea
# South Korea
# South Korea
# South Korea
# China
# Hong Kong
# India
# Japan
# China
# Hong Kong
# South Korea
# Japan
# Vietnam
# Japan
# Taiwan
# India
# Hong Kong
# Australia
# Japan
# Hong Kong
# Pakistan
# South Korea
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Taiwan
# India
# China
# United States
# Hong Kong
# Bangladesh
# South Korea
# Japan
# Japan
# Hong Kong
# Japan
# South Korea
# Taiwan
# Thailand
# Japan
# United States
# Hong Kong
# Taiwan
# Taiwan
# Taiwan
# Bangladesh
# Hong Kong
# Australia
# Mexico
# Hong Kong
# Japan
# India
# Mexico
# Japan
# Australia
# Hong Kong
# Malaysia
# United States
# China
# Australia
# China
# Japan
# Hong Kong
# China
# South Korea
# Hong Kong
# Japan
# Hong Kong
# China
# Hong Kong
# Australia
# Hong Kong
# Japan
# South Korea
# Hong Kong
# China
# Hong Kong
# Japan
# United States
# United States
# China
# Australia
# Taiwan
# Hong Kong
# China
# South Korea
# India
# Hong Kong
# United States
# Thailand
# Japan
# Taiwan
# China
# United States
# Japan
# Taiwan
# United States
# Hong Kong
# Hong Kong
# United States
# Japan
# Thailand
# Australia
# Japan
# Mexico
# Hong Kong
# Taiwan
# United States
# Japan
# United States
# Hong Kong
# Hong Kong
# Hong Kong
# Canada
# Hong Kong
# South Korea
# United States
# Nepal
# Japan
# Japan
# Thailand
# South Korea
# Hong Kong
# Japan
# Australia
# Japan
# Hong Kong
# Japan
# United States
# Japan
# Hong Kong
# India
# Singapore
# Malaysia
# Japan
# South Korea
# Australia
# Taiwan
# Hong Kong
# Taiwan
# Singapore
# Japan
# Vietnam
# South Korea
# Thailand
# Pakistan
# Hong Kong
# United States
# Hong Kong
# Japan
# United States
# Brazil
# United States
# Hong Kong
# UK
# UK
# UK
# UK
# UK
# UK
# Japan
# Hong Kong
# Pakistan
# Malaysia
# Taiwan
# Japan
# Hong Kong
# Australia
# South Korea
# China
# Japan
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# United States
# Singapore
# Taiwan
# Canada
# China
# Australia
# Taiwan
# Japan
# Taiwan
# South Korea
# Japan
# Mexico
# Taiwan
# China
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# United States
# Japan
# United States
# Brazil
# Vietnam
# United States
# Japan
# South Korea
# Hong Kong
# Hong Kong
# Hong Kong
# Hong Kong
# Hong Kong
# Hong Kong
# Japan
# United States
# Singapore
# Hong Kong
# Malaysia
# Japan
# Australia
# Japan
# Singapore
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# Hong Kong
# Canada
# Taiwan
# Taiwan
# Brazil
# Japan
# United States
# South Korea
# United States
# Japan
# South Korea
# Singapore
# Japan
# United States
# Malaysia
# Japan
# Singapore
# South Korea
# Taiwan
# Hong Kong
# Malaysia
# Hong Kong
# Hong Kong
# Hong Kong
# Hong Kong
# Hong Kong
# Hong Kong
# Hong Kong
# Hong Kong
# Hong Kong
# Hong Kong
# Hong Kong
# Hong Kong
# Hong Kong
# Hong Kong
# Hong Kong
# Indonesia
# Mexico
# Canada
# United States
# Taiwan
# Japan
# Hong Kong
# Australia
# South Korea
# Japan
# Hong Kong
# United States
# Hong Kong
# Mexico
# Hong Kong
# Japan
# Hong Kong
# Thailand
# Mexico
# United States
# Japan
# Australia
# United States
# Indonesia
# China
# Malaysia
# Mexico
# Japan
# Taiwan
# Malaysia
# Canada
# Hong Kong
# Malaysia
# Australia
# China
# Brazil
# Japan
# Malaysia
# South Korea
# Taiwan
# Japan
# Australia
# India
# Hong Kong
# Malaysia
# Japan
# Australia
# Mexico
# Japan
# Malaysia
# UK
# UK
# UK
# UK
# UK
# China
# Japan
# South Korea
# South Korea
# Canada
# Malaysia
# Taiwan
# Canada
# Thailand
# Australia
# Myanmar
# Netherlands
# China
# United States
# Hong Kong
# Taiwan
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# Malaysia
# Myanmar
# Japan
# Taiwan
# Singapore
# Hong Kong
# Japan
# China
# Malaysia
# Australia
# Japan
# Malaysia
# Malaysia
# Japan
# Germany
# South Korea
# Brazil
# Hong Kong
# Japan
# Malaysia
# United States
# United States
# Japan
# Taiwan
# Malaysia
# Myanmar
# UK
# UK
# UK
# UK
# Japan
# United States
# Thailand
# Japan
# United States
# Netherlands
# Singapore
# Taiwan
# United States
# Japan
# Thailand
# China
# Singapore
# Japan
# Bangladesh
# Taiwan
# Japan
# Malaysia
# Netherlands
# Japan
# Myanmar
# Japan
# Myanmar
# United States
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Hungary
# Netherlands
# Cambodia
# Thailand
# Japan
# United States
# Singapore
# China
# Netherlands
# Indonesia
# United States
# Japan
# Japan
# Netherlands
# United States
# Germany
# Japan
# Singapore
# United States
# Myanmar
# Japan
# United States
# Hungary
# Japan
# Singapore
# Vietnam
# Finland
# Hungary
# Japan
# Myanmar
# Singapore
# Malaysia
# Netherlands
# China
# Japan
# Hungary
# Japan
# Myanmar
# Japan
# South Korea
# United States
# Japan
# Myanmar
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# United States
# Malaysia
# Taiwan
# Japan
# Thailand
# Hungary
# Germany
# Japan
# Thailand
# Malaysia
# Myanmar
# United States
# China
# Malaysia
# Netherlands
# Japan
# Cambodia
# Japan
# United States
# Indonesia
# Japan
# Myanmar
# Hungary
# United States
# Japan
# United States
# Malaysia
# Malaysia
# Netherlands
# United States
# Bangladesh
# Japan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Thailand
# Japan
# Taiwan
# Taiwan
# Taiwan
# South Korea
# Cambodia
# China
# United States
# Malaysia
# Indonesia
# United States
# Taiwan
# Thailand
# Japan
# Malaysia
# Vietnam
# Japan
# Netherlands
# Germany
# China
# Netherlands
# Malaysia
# Japan
# Thailand
# Thailand
# Malaysia
# Bangladesh
# Hungary
# Thailand
# United States
# China
# United States
# United States
# Netherlands
# Thailand
# Japan
# Canada
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# United States
# Malaysia
# Japan
# Netherlands
# Canada
# Malaysia
# South Korea
# Taiwan
# China
# China
# China
# China
# China
# China
# China
# China
# China
# Malaysia
# Japan
# Cambodia
# South Korea
# United States
# Finland
# Japan
# Taiwan
# United States
# Japan
# Thailand
# Malaysia
# Netherlands
# Taiwan
# Bangladesh
# South Korea
# United States
# Japan
# Taiwan
# Indonesia
# Thailand
# Canada
# Malaysia
# Japan
# Netherlands
# Taiwan
# Myanmar
# Malaysia
# United States
# China
# Japan
# Thailand
# Indonesia
# Malaysia
# China
# Singapore
# Germany
# Malaysia
# Cambodia
# Taiwan
# Taiwan
# Japan
# Taiwan
# Vietnam
# Taiwan
# Finland
# China
# Malaysia
# Indonesia
# Malaysia
# Thailand
# Vietnam
# Sarawak
# Myanmar
# Thailand
# China
# Malaysia
# Japan
# Malaysia
# Taiwan
# Hungary
# Sarawak
# Canada
# Malaysia
# Malaysia
# China
# Thailand
# Japan
# Japan
# Taiwan
# Malaysia
# United States
# Sarawak
# Thailand
# Thailand
# Thailand
# Myanmar
# Bangladesh
# Thailand
# China
# China
# China
# China
# China
# China
# China
# China
# China
# China
# Malaysia
# Taiwan
# United States
# South Korea
# Malaysia
# China
# South Korea
# Taiwan
# Canada
# Malaysia
# Indonesia
# Vietnam
# Thailand
# Taiwan
# Vietnam
# Vietnam
# Malaysia
# Vietnam
# Thailand
# China
# Hong Kong
# Vietnam
# South Korea
# Pakistan
# Thailand
# China
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# South Korea
# China
# Taiwan
# Canada
# Vietnam
# Philippines
# Malaysia
# South Korea
# Canada
# United States
# Taiwan
# Malaysia
# Taiwan
# Germany
# Pakistan
# Thailand
# South Korea
# Vietnam
# Malaysia
# Japan
# China
# Malaysia
# Canada
# Taiwan
# Japan
# Thailand
# China
# Malaysia
# United States
# Japan
# Malaysia
# Singapore
# Taiwan
# Malaysia
# China
# China
# Malaysia
# Japan
# Pakistan
# Philippines
# Vietnam
# Japan
# Malaysia
# Japan
# Malaysia
# Hong Kong
# Japan
# Indonesia
# Vietnam
# South Korea
# Taiwan
# India
# Thailand
# United States
# Malaysia
# China
# Japan
# South Korea
# Taiwan
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Vietnam
# South Korea
# Malaysia
# Japan
# Thailand
# India
# South Korea
# Taiwan
# Malaysia
# China
# Malaysia
# Japan
# Malaysia
# Thailand
# Japan
# India
# Japan
# Vietnam
# United States
# Singapore
# Malaysia
# Thailand
# China
# Canada
# Malaysia
# India
# UK
# Sweden
# Malaysia
# Thailand
# Japan
# Malaysia
# Canada
# Japan
# Taiwan
# Hong Kong
# Malaysia
# United States
# India
# Singapore
# Taiwan
# China
# Japan
# Hong Kong
# Thailand
# Vietnam
# Hong Kong
# Malaysia
# Vietnam
# Philippines
# Philippines
# Philippines
# Philippines
# Philippines
# Philippines
# Philippines
# Malaysia
# Singapore
# South Korea
# Vietnam
# Japan
# Thailand
# India
# Malaysia
# Sweden
# Japan
# South Korea
# Malaysia
# Thailand
# Hong Kong
# Taiwan
# Hong Kong
# Japan
# Malaysia
# Singapore
# India
# Pakistan
# China
# United States
# China
# Japan
# Malaysia
# Vietnam
# South Korea
# United States
# China
# Malaysia
# Indonesia
# Japan
# Thailand
# South Korea
# Germany
# India
# Taiwan
# Sweden
# Taiwan
# United States
# Malaysia
# Hong Kong
# Japan
# China
# South Korea
# United States
# Thailand
# Thailand
# Germany
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# Thailand
# Germany
# Thailand
# Thailand
# Thailand
# Germany
# Malaysia
# United States
# Taiwan
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Japan
# Malaysia
# United States
# United States
# Singapore
# United States
# Taiwan
# Malaysia
# Japan
# Hong Kong
# China
# Singapore
# Malaysia
# Singapore
# Singapore
# Singapore
# South Korea
# Colombia
# Japan
# United States
# South Korea
# Malaysia
# UK
# Vietnam
# United States
# China
# Japan
# Vietnam
# South Korea
# Taiwan
# Japan
# Hong Kong
# South Korea
# Taiwan
# Hong Kong
# Taiwan
# Malaysia
# China
# Philippines
# United States
# Indonesia
# India
# Thailand
# UK
# Indonesia
# Japan
# South Korea
# Vietnam
# Singapore
# Taiwan
# Japan
# United States
# South Korea
# Malaysia
# United States
# Pakistan
# Indonesia
# UK
# South Korea
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# UK
# South Korea
# Canada
# Thailand
# Taiwan
# Germany
# UK
# United States
# Hong Kong
# China
# Hong Kong
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# Malaysia
# South Korea
# Japan
# United States
# United States
# United States
# Malaysia
# Canada
# Indonesia
# Thailand
# UK
# United States
# United States
# United States
# United States
# United States
# United States
# Indonesia
# Japan
# Vietnam
# Taiwan
# China
# Malaysia
# Singapore
# Thailand
# China
# South Korea
# Japan
# Thailand
# Malaysia
# Japan
# Taiwan
# South Korea
# UK
# South Korea
# Indonesia
# Japan
# Indonesia
# United States
# Thailand
# South Korea
# Japan
# Singapore
# Taiwan
# Hong Kong
# Canada
# Thailand
# Hong Kong
# South Korea
# Canada
# South Korea
# Indonesia
# Taiwan
# Taiwan
# Thailand
# Singapore
# Colombia
# Vietnam
# South Korea
# China
# Hong Kong
# Japan
# UK
# Philippines
# United States
# South Korea
# Singapore
# Japan
# Taiwan
# UK
# South Korea
# Vietnam
# Malaysia
# Taiwan
# Taiwan
# UK
# South Korea
# Singapore
# UK
# Hong Kong
# Taiwan
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Japan
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Thailand
# Hong Kong
# United States
# UK
# Thailand
# South Korea
# Colombia
# Taiwan
# Japan
# United States
# Hong Kong
# China
# Hong Kong
# United States
# Japan
# Malaysia
# Indonesia
# Japan
# Thailand
# South Korea
# Hong Kong
# UK
# Colombia
# Indonesia
# Taiwan
# Malaysia
# Japan
# Japan
# Canada
# China
# United States
# South Korea
# Malaysia
# Germany
# Indonesia
# Japan
# Japan
# China
# Hong Kong
# UK
# Indonesia
# Indonesia
# China
# Thailand
# Hong Kong
# Taiwan
# UK
# China
# Japan
# Taiwan
# Thailand
# Colombia
# Indonesia
# Japan
# Taiwan
# Japan
# Thailand
# South Korea
# Japan
# United States
# Malaysia
# South Korea
# Germany
# Taiwan
# Indonesia
# Japan
# Japan
# China
# South Korea
# Colombia
# UK
# Japan
# South Korea
# UK
# South Korea
# Taiwan
# Japan
# United States
# Indonesia
# Japan
# Indonesia
# Japan
# Indonesia
# United States
# UK
# Japan
# Canada
# Japan
# UK
# Taiwan
# United States
# Canada
# China
# Japan
# Indonesia
# South Korea
# Japan
# Hong Kong
# UK
# Vietnam
# United States
# China
# Taiwan
# Japan
# Nepal
# Nepal
# Nepal
# Nepal
# Nepal
# Nepal
# Nepal
# Nepal
# Nepal
# Nepal
# Nepal
# Nepal
# Nepal
# Japan
# Singapore
# Japan
# Indonesia
# South Korea
# Hong Kong
# UK
# Taiwan
# United States
# Japan
# Philippines
# Canada
# Indonesia
# United States
# South Korea
# Japan
# Japan
# China
# Indonesia
# UK
# Canada
# United States
# Japan
# United States
# Indonesia
# South Korea
# Thailand
# China
# South Korea
# Indonesia
# China
# Hong Kong
# Japan
# South Korea
# Canada
# Japan
# UK
# Indonesia
# Estonia
# Estonia
# Indonesia
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Malaysia
# UK
# Vietnam
# Canada
# Japan
# Indonesia
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Japan
# South Korea
# Japan
# Singapore
# Japan
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# Malaysia
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Japan
# Hong Kong
# Canada
# South Korea
# Japan
# United States
# United States
# China
# China
# China
# UK
# Canada
# United States
# Japan
# South Korea
# China
# Taiwan
# Canada
# Japan
# Thailand
# South Korea
# South Korea
# South Korea
# South Korea
# South Korea
# South Korea
# South Korea
# South Korea
# South Korea
# South Korea
# South Korea
# South Korea
# South Korea
# South Korea
# South Korea
# United States
# United States
# Japan
# Vietnam
# Holland
# United States
# China
# Canada
# South Korea
# Hong Kong
# Poland
# China
# Thailand
# United States
# Canada
# South Korea
# United States
# UK
# South Korea
# Japan
# United States
# UK
# Thailand
# Holland
# Singapore
# Singapore
# United States
# South Korea
# Poland
# Australia
# South Korea
# UK
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# Japan
# South Korea
# UK
# United States
# China
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# Japan
# UK
# United States
# Australia
# United States
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# Japan
# UK
# Poland
# South Korea
# UK
# Australia
# United States
# United States
# UK
# Thailand
# Poland
# China
# UK
# Thailand
# UK
# United States
# Thailand
# United States
# United States
# United States
# South Korea
# South Korea
# China
# United States
# Vietnam
# China
# South Korea
# Malaysia
# South Korea
# United States
# Malaysia
# Thailand
# South Korea
# United States
# United States
# South Korea
# Vietnam
# Japan
# Thailand
# Japan
# South Korea
# United States
# United States
# South Korea
# Indonesia
# United States
# South Korea
# Malaysia
# United States
# Japan
# South Korea
# Thailand
# Indonesia
# United States
# Fiji
# China
# Fiji
# Vietnam
# Indonesia
# South Korea
# South Korea
# Indonesia
# Vietnam
# Vietnam
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# Indonesia
# South Korea
# China
# South Korea
# United States
# United States
# Indonesia
# Thailand
# Japan
# Vietnam
# United States
# China
# Indonesia
# Vietnam
# South Korea
# Indonesia
# China
# Thailand
# Taiwan
# Indonesia
# United States
# Vietnam
# China
# United States
# Indonesia
# South Korea
# Thailand
# Vietnam
# China
# South Korea
# Indonesia
# China
# United States
# United States
# China
# Japan
# Vietnam
# South Korea
# Malaysia
# United States
# China
# South Korea
# China
# South Korea
# Indonesia
# United States
# Vietnam
# Canada
# Indonesia
# Thailand
# China
# Vietnam
# Japan
# South Korea
# South Korea
# South Korea
# South Korea
# Japan
# South Korea
# South Korea
# South Korea
# China
# Thailand
# Japan
# Indonesia
# Taiwan
# Vietnam
# China
# Indonesia
# Canada
# China
# Canada
# Indonesia
# South Korea
# Thailand
# Indonesia
# South Korea
# Japan
# Thailand
# China
# Indonesia
# Vietnam
# Canada
# United States
# China
# Dubai
# Vietnam
# China
# Indonesia
# Canada
# United States
# Japan
# Thailand
# Indonesia
# Taiwan
# South Korea
# Canada
# Indonesia
# China
# United States
# United States
# Vietnam
# South Korea
# Indonesia
# Malaysia
# Canada
# Indonesia
# China
# Indonesia
# Thailand
# United States
# Indonesia
# Hong Kong
# United States
# Thailand
# Thailand
# Thailand
# Indonesia
# South Korea
# India
# Taiwan
# United States
# United States
# United States
# China
# Indonesia
# Japan
# South Korea
# United States
# South Korea
# United States
# South Korea
# United States
# United States
# United States
# United States
# China
# South Korea
# Philippines
# Malaysia
# Dubai
# Taiwan
# Indonesia
# China
# Japan
# Vietnam
# United States
# South Korea
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Japan
# United States
# Dubai
# United States
# South Korea
# United States
# Vietnam
# Indonesia
# South Korea
# United States
# Hong Kong
# South Korea
# Vietnam
# United States
# Taiwan
# Thailand
# Taiwan
# China
# United States
# United States
# Japan
# United States
# Japan
# United States
# United States
# United States
# United States
# Japan
# Vietnam
# China
# South Korea
# Malaysia
# United States
# Thailand
# South Korea
# Hong Kong
# Indonesia
# Indonesia
# China
# South Korea
# Indonesia
# South Korea
# Vietnam
# Malaysia
# South Korea
# China
# Indonesia
# South Korea
# South Korea
# South Korea
# UK
# UK
# Vietnam
# Japan
# Vietnam
# United States
# Taiwan
# Thailand
# United States
# South Korea
# Japan
# Japan
# Philippines
# United States
# South Korea
# China
# United States
# Indonesia
# Thailand
# China
# Japan
# Indonesia
# China
# UK
# South Korea
# Thailand
# Japan
# South Korea
# South Korea
# Taiwan
# Thailand
# Vietnam
# China
# Japan
# Thailand
# Singapore
# Japan
# South Korea
# China
# South Korea
# South Korea
# Thailand
# Taiwan
# China
# Philippines
# Vietnam
# South Korea
# UK
# China
# Taiwan
# Japan
# South Korea
# Vietnam
# Japan
# South Korea
# Japan
# India
# Japan
# Hong Kong
# Vietnam
# United States
# UK
# Taiwan
# Taiwan
# Singapore
# UK
# South Korea
# Thailand
# UK
# Taiwan
# South Korea
# Taiwan
# United States
# Philippines
# Thailand
# UK
# United States
# United States
# South Korea
# South Korea
# UK
# UK
# Thailand
# Vietnam
# Vietnam
# Taiwan
# Taiwan
# Taiwan
# China
# Vietnam
# United States
# United States
# China
# China
# South Korea
# UK
# Japan
# UK
# India
# Vietnam
# United States
# Japan
# South Korea
# Vietnam
# South Korea
# Japan
# South Korea
# UK
# Taiwan
# Thailand
# UK
# South Korea
# Japan
# Thailand
# China
# UK
# Indonesia
# UK
# Thailand
# South Korea
# Indonesia
# UK
# Japan
# Indonesia
# UK
# Philippines
# Thailand
# China
# Holland
# Japan
# Indonesia
# Thailand
# United States
# Japan
# Philippines
# Thailand
# South Korea
# Thailand
# Thailand
# South Korea
# Hong Kong
# Thailand
# Thailand
# United States
# Holland
# Thailand
# United States
# China
# Hong Kong
# China
# South Korea
# Japan
# Taiwan
# Singapore
# China
# United States
# South Korea
# United States
# Japan
# China
# South Korea
# Japan
# Singapore
# Taiwan
# South Korea
# China
# South Korea
# China
# Pakistan
# Thailand
# Thailand
# South Korea
# United States
# China
# Taiwan
# Japan
# United States
# South Korea
# Singapore
# South Korea
# Vietnam
# China
# South Korea
# China
# Hong Kong
# Hong Kong
# China
# South Korea
# South Korea
# Japan
# Japan
# United States
# United States
# South Korea
# Taiwan
# South Korea
# United States
# United States
# Vietnam
# Japan
# United States
# United States
# United States
# United States
# South Korea
# Vietnam
# Vietnam
# United States
# Thailand
# South Korea
# United States
# South Korea
# Japan
# United States
# Taiwan
# Malaysia
# Taiwan
# China
# United States
# United States
# Japan
# Japan
# South Korea
# Taiwan
# Taiwan
# Vietnam
# Hong Kong
# Taiwan
# South Korea
# Philippines
# South Korea
# South Korea
# United States
# Thailand
# South Korea
# South Korea
# Taiwan
# Indonesia
# Indonesia
# Philippines
# Taiwan
# Taiwan
# Philippines
# Philippines
# China
# Singapore
# Vietnam
# United States
# Taiwan
# South Korea
# Vietnam
# Japan
# United States
# Japan
# Taiwan
# Vietnam
# United States
# Taiwan
# Hong Kong
# Taiwan
# Japan
# Thailand
# Philippines
# Philippines
# Vietnam
# South Korea
# Vietnam
# Malaysia
# Vietnam
# United States
# Hong Kong
# Japan
# Hong Kong
# South Korea
# South Korea
# Philippines
# Vietnam
# South Korea
# South Korea
# China
# Japan
# Japan
# Japan
# Thailand
# United States
# United States
# United States
# Taiwan
# Japan
# Philippines
# Philippines
# Vietnam
# South Korea
# United States
# Taiwan
# Hong Kong
# Hong Kong
# Vietnam
# Vietnam
# United States
# Canada
# United States
# Hong Kong
# South Korea
# Thailand
# Vietnam
# Philippines
# Singapore
# Hong Kong
# Japan
# Vietnam
# United States
# United States
# United States
# Hong Kong
# Philippines
# United States
# South Korea
# United States
# United States
# United States
# United States
# United States
# South Korea
# South Korea
# Taiwan
# South Korea
# Japan
# South Korea
# Indonesia
# South Korea
# Vietnam
# Japan
# Philippines
# United States
# United States
# South Korea
# Japan
# United States
# United States
# South Korea
# Thailand
# Vietnam
# Thailand
# South Korea
# Vietnam
# Thailand
# Thailand
# South Korea
# South Korea
# Taiwan
# Thailand
# United States
# United States
# Taiwan
# United States
# Taiwan
# Taiwan
# South Korea
# South Korea
# Philippines
# Vietnam
# Philippines
# South Korea
# United States
# Thailand
# South Korea
# Philippines
# Thailand
# South Korea
# South Korea
# China
# Taiwan
# Philippines
# South Korea
# South Korea
# Hong Kong
# Japan
# South Korea
# Taiwan
# South Korea
# South Korea
# Hong Kong
# South Korea
# South Korea
# South Korea
# Japan
# Hong Kong
# Hong Kong
# South Korea
# Hong Kong
# Thailand
# South Korea
# South Korea
# United States
# Vietnam
# Thailand
# Thailand
# Taiwan
# Thailand
# Vietnam
# South Korea
# Taiwan
# South Korea
# United States
# Thailand
# Vietnam
# United States
# Vietnam
# United States
# Vietnam
# Vietnam
# United States
# Vietnam
# Thailand
# United States
# United States
# Thailand
# Vietnam
# United States
# United States
# United States
# Taiwan
# Taiwan
# Singapore
# Japan
# Thailand
# South Korea
# Japan
# Japan
# Thailand
# United States
# Japan
# South Korea
# United States
# Singapore
# Singapore
# Singapore
# Japan
# Singapore
# Indonesia
# Indonesia
# Philippines
# Japan
# Vietnam
# Philippines
# United States
# South Korea
# Thailand
# Singapore
# Japan
# United States
# Taiwan
# South Korea
# United States
# South Korea
# United States
# United States
# United States
# United States
# United States
# Vietnam
# China
# United States
# China
# United States
# South Korea
# United States
# United States
# United States
# United States
# United States
# United States
# South Korea
# Japan
# South Korea
# India
# Japan
# Vietnam
# Thailand
# South Korea
# Taiwan
# Malaysia
# India
# South Korea
# South Korea
# South Korea
# Japan
# Japan
# United States
# Japan
# China
# Japan
# Thailand
# Thailand
# Vietnam
# South Korea
# South Korea
# Philippines
# Taiwan
# Thailand
# South Korea
# Japan
# South Korea
# Japan
# Thailand
# United States
# Hong Kong
# Taiwan
# Vietnam
# Japan
# South Korea
# Japan
# Thailand
# Thailand
# Philippines
# United States
# Philippines
# United States
# United States
# Taiwan
# Japan
# South Korea
# Japan
# Japan
# Japan
# Thailand
# Japan
# South Korea
# Thailand
# United States
# South Korea
# Thailand
# China
# Taiwan
# United States
# Thailand
# Taiwan
# South Korea
# China
# Taiwan
# Taiwan
# Japan
# South Korea
# Thailand
# Vietnam
# Thailand
# Japan
# Japan
# Thailand
# Hong Kong
# South Korea
# South Korea
# Taiwan
# South Korea
# South Korea
# Thailand
# South Korea
# South Korea
# South Korea
# South Korea
# South Korea
# Philippines
# Thailand
# United States
# South Korea
# Thailand
# Indonesia
# United States
# Taiwan
# Indonesia
# Taiwan
# Taiwan
# Taiwan
# Taiwan
# Vietnam
# Vietnam
# Taiwan
# Thailand
# Philippines
# Thailand
# Vietnam
# China
# Taiwan
# South Korea
# Thailand
# Taiwan
# Japan
# South Korea
# Japan
# Japan
# Taiwan
# Taiwan
# Japan
# Japan
# Japan
# Indonesia
# Indonesia
# Japan
# Japan
# Japan
# Japan
# Japan
# China
# Taiwan
# United States
# United States
# United States
# United States
# Japan
# India
# India
# India
# India
# Taiwan
# Hong Kong
# Hong Kong
# China
# China
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Indonesia
# Taiwan
# Vietnam
# Thailand
# Philippines
# Philippines
# Philippines
# Philippines
# Philippines
# Thailand
# United States
# Singapore
# Singapore
# Japan
# Japan
# Thailand
# Japan
# Japan
# Japan
# Japan
# Japan
# United States
# South Korea
# South Korea
# South Korea
# South Korea
# South Korea
# Philippines
# South Korea
# South Korea
# South Korea
# Japan
# Japan
# South Korea
# United States
# South Korea
# Taiwan
# Vietnam
# Vietnam
# Vietnam
# Thailand
# Thailand
# Thailand
# United States

# %% [markdown]
# ## The Ramen Olympics
#
# To get a better handle on the countries represented here, let's clean that list up a bit. Let's get each country represented at least once in the ramen review dataset, listed only once each.
#
# To do so, let's take the code from the previous task and expand it so that it only prints each country once.
#
# - Define an empty list `countries`.
# - Loop through the `country` column in `ramen`.
# - In your loop, use an `if` statement to `append` the country name to the list `countries` *only* if it is not already in `countries`.
# - Create another `for` loop that iterates through the list countries and prints each country in the list.
#
# <hr />
#
# Note: the `set()` function can also be used to remove duplicates from a list; but, for now, let's take the opportunity to practice `for` loops and `if` statements.

# %%
# Create an empty list `countries`
countries = []

# Loop through the `country` column in `ramen`
for i in ramen['country']:
    # Append country name to `countries`, but only if country name isn't already in `countries`
    if i not in countries:
        countries.append(i)

# Print every country name in `countries`
for j in countries:
    print(j)
# Out:
# Taiwan
# Japan
# Singapore
# United States
# Phlippines
# China
# Hong Kong
# India
# South Korea
# Malaysia
# Indonesia
# Nigeria
# Thailand
# Vietnam
# Ghana
# Germany
# Hungary
# Mexico
# Fiji
# Australia
# Pakistan
# Bangladesh
# Canada
# Nepal
# Brazil
# UK
# Myanmar
# Netherlands
# Cambodia
# Finland
# Sarawak
# Philippines
# Sweden
# Colombia
# Estonia
# Holland
# Poland
# Dubai

# %% [markdown]
# ## The Most Prolific Ramen Nations
#
# It's fun to see all the countries that produce ramen but which country produces ramen that is most reviewed by The Ramen Reviewer? And, even more importantly, which country produces the best ramen? Let's see which country's ramen has been reviewed the most at The Ramen Reviewer first.
#
# In order to do so, let's create a dictionary `country_count` that contains the number of ramen varieties reviewed at The Ramen Reviewer and then print them out.
#
# - Create an empty dictionary, `country_count`.
# - Loop through the `country` column in `ramen`.
# - If the country is not already in `country_count.keys()`, assign a value of `1` to that country in `country_count`.
# - If the country is already in `country_count.keys()`, add 1 to its existing value.
# - Create another `for` loop that iterates through the keys and values in `country_count.items()` and prints each country and its total number of reviews.
#
# <hr />
#
# Note that there are other, simpler ways to count the items in a dataframe, but doing it this way will help us master the logic of `for` loops and `dictionaries`, as well.

# %%
# Define an empty dictionary, `country_count`
country_count = {}

# Loop through the `country` column in `ramen`
for i in ramen['country']:
    # Count the number of countries
    if  i not in country_count.keys():
        country_count[i] = 1

    else:
        country_count[i] += 1


# Printing every country name in `country_count` and its count
for i, keys in country_count.items():
    print("Country: "+str(i))
    print("Count: "+str(keys))
# Out:
# Country: Taiwan
# Count: 229
# Country: Japan
# Count: 381
# Country: Singapore
# Count: 122
# Country: United States
# Count: 340
# Country: Phlippines
# Count: 1
# Country: China
# Count: 175
# Country: Hong Kong
# Count: 144
# Country: India
# Count: 39
# Country: South Korea
# Count: 326
# Country: Malaysia
# Count: 158
# Country: Indonesia
# Count: 141
# Country: Nigeria
# Count: 2
# Country: Thailand
# Count: 191
# Country: Vietnam
# Count: 108
# Country: Ghana
# Count: 2
# Country: Germany
# Count: 27
# Country: Hungary
# Count: 9
# Country: Mexico
# Count: 25
# Country: Fiji
# Count: 4
# Country: Australia
# Count: 22
# Country: Pakistan
# Count: 9
# Country: Bangladesh
# Count: 7
# Country: Canada
# Count: 41
# Country: Nepal
# Count: 14
# Country: Brazil
# Count: 5
# Country: UK
# Count: 69
# Country: Myanmar
# Count: 14
# Country: Netherlands
# Count: 15
# Country: Cambodia
# Count: 5
# Country: Finland
# Count: 3
# Country: Sarawak
# Count: 3
# Country: Philippines
# Count: 47
# Country: Sweden
# Count: 3
# Country: Colombia
# Count: 6
# Country: Estonia
# Count: 2
# Country: Holland
# Count: 4
# Country: Poland
# Count: 4
# Country: Dubai
# Count: 3

# %% [markdown]
# ## Ordering ramen
#
# It looks like Japan has produced the most ramen reviewed by The Ramen Rater. Let's confirm this and also make things easier to read by ranking these review counts.
#
# So let's count the number of occurrences of each country the `pandas` way and print the results in descending order.
#
# - Use the `.value_counts()` method to count the unique values in `ramen['country']`, and assign the result to `country_count`
# 	- You might not have seen the `.value_counts()` method before but it's very useful and simple so this is a good time to explore it and add it to your toolbox.
# - Print `country_count`.
#
# <hr />
#
# This is a faster and more efficient way to do what we did in the previous task and makes use of a built-in `pandas` method. It even arranges the values for us automatically! Be sure to add `.value_counts()` to your notes for future usage.

# %%
# Redefine `country_count` the pandas way
country_count = ramen['country'].value_counts()

# Print `country_count`
print(country_count)
# Out:
# country
# Japan            381
# United States    340
# South Korea      326
# Taiwan           229
# Thailand         191
# China            175
# Malaysia         158
# Hong Kong        144
# Indonesia        141
# Singapore        122
# Vietnam          108
# UK                69
# Philippines       47
# Canada            41
# India             39
# Germany           27
# Mexico            25
# Australia         22
# Netherlands       15
# Nepal             14
# Myanmar           14
# Pakistan           9
# Hungary            9
# Bangladesh         7
# Colombia           6
# Cambodia           5
# Brazil             5
# Poland             4
# Holland            4
# Fiji               4
# Sarawak            3
# Sweden             3
# Finland            3
# Dubai              3
# Estonia            2
# Nigeria            2
# Ghana              2
# Phlippines         1
# Name: count, dtype: int64

# %% [markdown]
# ## Summarizing Ramen Reviews
#
# Now that we know whose Ramens were reviewed the most -- Asian countries and the US, mainly -- let's find out whose are the best! To start, let's see how the ramen reviews are distributed in general.
#
# Let's plot a histogram of ramen ratings. (Use `ratings`, which contains only the numeric values in `ramen['rating']`.)
#
# - Create a histogram based on `ratings`.
# - Try a few different amounts of bins and keep the one that best exemplifies the distribution of the data.
# - Add appropriate X and Y axis labels and a plot title.

# %%
import numpy as np
# Remove non-numeric values from ramen['rating']
ratings = pd.to_numeric(ramen['rating'], errors='coerce').dropna()
bins=int(np.sqrt(len(ratings)))
print(bins)
# Histogram of ramen reviews
plt.hist(ratings,bins)
plt.xlabel("Ratings")
plt.ylabel("Count")
plt.title("Ramen Ratings Histogram")
# Out:
# 51
# Text(0.5, 1.0, 'Ramen Ratings Histogram')

# %% [markdown]
# ## Which country has the best ramen?
#
# Now that we know the general distribution of ramen ratings, let's find the average ramen rating for countries in the dataset. Since some countries were only reviewed a small number of times, their averages could easily be swayed by outliers. So let's focus just on the 10 countries that were reviewed the most often.
#
# Let's find and print the average rating for ramen varieties from each of the 10 most reviewed countries.
#
# - Import `numpy` as `np`.
# - Make a list `high_volume` containing the first 10 countries in `country_count`. (Remember that the country names are `keys` in that dictionary.)
# - Loop through the countries in the new list `high_volume`.
# - For each of those countries, subset `ramen['rating']` to include only the reviews where `ramen['country']` corresponds to the country in question, and then use `np.mean()` to find the average rating for that country.
# - Still in that `for` loop, assign that average rating (the value) to the country name (the key) in the dictionary `average_ratings`.
# - Loop through the new dictionary `average_ratings` and print each key-value pair, separated by a colon and a space.
#
# <hr />
#
# As above, there is a simpler `pandas` way to do this, but this exercise will help us further solidify the logic of loops, dictionaries, and dataframes. Plus, we'll see the simpler `pandas` way below.
#
# Keep in mind that even though the `for` loop sounds complicated, it is made of several pieces, each of which you have done before, and each of which is simple *on its own*. Be slow and deliberate about breaking down those steps, and you'll definitely be able to figure it out!

# %%
# Import numpy as np
import numpy as np
# Clean ramen['rating'] to remove non-numeric values entirely
ramen['rating'] = pd.to_numeric(ramen['rating'], errors='coerce').dropna()

# Identify the 10 countries rated most often
high_volume = country_count[0:10].keys()

# Create an empty dictionary of ramen ratings
average_ratings = {}

# Loop through countries in high_volume
for i in high_volume:
    # Assign the average rating for `country` to `average_ratings`
    inter = ramen[ramen['country'] == i]
    #print(inter)
    average_ratings[i]=np.mean(inter['rating'])

# Loop through the new dictionary `average_ratings` and print each key-value pair
for i,keys in average_ratings.items():
    print("Country: "+str(i))
    print("Avg rating: "+str(keys))
# Out:
# Country: Japan
# Avg rating: 3.982915567282322
# Country: United States
# Avg rating: 3.4833584337349395
# Country: South Korea
# Avg rating: 3.7976851851851854
# Country: Taiwan
# Avg rating: 3.688864628820961
# Country: Thailand
# Avg rating: 3.380104712041885
# Country: China
# Avg rating: 3.434571428571428
# Country: Malaysia
# Avg rating: 4.16656050955414
# Country: Hong Kong
# Avg rating: 3.8093749999999997
# Country: Indonesia
# Avg rating: 4.067375886524823
# Country: Singapore
# Avg rating: 4.103305785123967

# %% [markdown]
# ## Ranking the countries
#
# That list is great, but let's rank those countries according to their average rating.
#
# This isn't so much an exercise as code to look at, in anticipation of things we'll do in the future. Lists, dictionaries, and for loops can be very useful but, as our data gets bigger, our code will get simpler (and faster!) if we learn some of the built-in functions and methods that the `pandas` package provides.
#
# Simply look over this code and see if you can figure out what it's doing.
#
# It is doing what was done above, it is taking the top 10 countries and raking it by the mean of the ratings

# %%
# Filter only the ramen ratings from countries in `high_volume`
high_volume_ratings = ramen[ramen['country'].isin(high_volume)]

# Use the `pandas` methods `groupby()` and `mean()` to summarize dataframe with average ratings by country
average_ratings = high_volume_ratings[['country', 'rating']].groupby(['country']).mean()

# Print out average ratings by country, sorted in descending order by rating
print(average_ratings.sort_values('rating', ascending = False))
# Out:
#                  rating
# country
# Malaysia       4.166561
# Singapore      4.103306
# Indonesia      4.067376
# Japan          3.982916
# Hong Kong      3.809375
# South Korea    3.797685
# Taiwan         3.688865
# United States  3.483358
# China          3.434571
# Thailand       3.380105

# %% [markdown]
# ## Top ramen brands
#
# It looks like Malaysia wins the ramen olympics! It's the country with the highest average ramen rating, at least out of the 10 countries reviewed the most. But which brand is ramen is best?
#
# Take the provided code (from the `pandas` way to count, subset, and average ratings by _country_ above) and alter it so that it counts, subsets, and averages ramen ratings by _brand_ instead.
#
# <hr />
#
# This is the all-important data science skill of finding, copying, pasting, and tweaking existing code to fit your needs. It's part of the hacker ethic -- don't reinvent the wheel but instead spend your time inventing new kinds of wheels! It's also a great way to begin to figure out how new objects, methods, and functions work. After all, most of the code that you copy, paste, and tweak, rather than write from scratch yourself, will contain at least _something_ that's new to you. See if you can make this code work for your current purpose.

# %%
# Redefine `country_count` the pandas way
country_count = ramen['brand'].value_counts()

# Filter only the ramen ratings from countries in `high_volume`
high_volume_ratings = ramen[ramen['brand'].isin(country_count[0:10].keys())]


# Use the `pandas` methods `groupby()` and `mean()` to summarize dataframe with average ratings by country
average_ratings = high_volume_ratings[['brand', 'rating']].groupby(['brand']).mean()

# Print out average ratings by country, sorted in descending order by rating
print(average_ratings.sort_values('rating', ascending =False))
# Out:
#                  rating
# brand
# Indomie        4.055556
# Samyang Foods  4.050000
# Nongshim       4.033981
# Paldo          3.996377
# Nissin         3.942148
# Myojo          3.840278
# Mama           3.628873
# Maruchan       3.595370
# Ottogi         3.408696
# Lucky Me!      3.294118

# %% [markdown]
# ## Ranking ramen styles
#
# Indome, Samyang Foods, and Nongshim are neck and neck! Must be some great ramen. The Ramen Rater has also included information on the _style_ of ramen (pack, bowl, cup, tray, box, etc.). Which style does The Ramen Rater prefer?
#
# As in the previous task, take existing code and tweak it to find whether ramen in a pack, a bowl, a cup, or a tray is the most highly rated on average. (We're focusing on those four styles because the others only appear a small number of times in comparison, some only once.)
#
# - Don't change the definition of `key_styles`. It's already ready for you.
# - Watch the `.isin()` method. Since we defined `key_styles` as a list, you don't need the first 10 keys of a sorted dataframe. You just need the list `key_styles`.
# - Change anything else (besides `key_styles`) that you need to in order to make the code do what you want it to do.

# %%
# Focus in on the four styles reviewed most frequently
key_styles = ['Pack', 'Bowl', 'Cup', 'Tray']

# Filter only the ramen ratings from countries in `high_volume`
high_volume_ratings = ramen[ramen['style'].isin(key_styles)]
# Use the `pandas` methods `groupby()` and `mean()` to summarize dataframe with average ratings by country
average_ratings = high_volume_ratings[['style', 'rating']].groupby('style').mean()

# Print out average ratings by country, sorted in descending order by rating
print(average_ratings.sort_values('rating', ascending =False))
# Out:
#          rating
# style
# Pack   3.709968
# Bowl   3.691440
# Tray   3.567045
# Cup    3.516436

# %% [markdown]
# ## Conclusion
#
# We have our winners! The best ramen, by country, comes from Malaysia. The best ramen by brand comes from Indome, Samyang Foods, and Nongshim. And the best ramen style, according to The Ramen Rater, is the pack. (Though without performing proper statistical tests, we can't rule out the bowl either, apparently!) The Ramen Rater did a great service for us by providing these ratings. And now that we've done the data analysis, it's time to go shopping!
